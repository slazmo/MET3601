# %% [markdown]
# # Lab 6:  Signs and Sines  (25 pts)

# %% [markdown]
# ## Question 1: Damped Sine Wave (5 pts)
# Plot a damped sine wave using the equation:
#
# $$ y = e^{-0.1x} \cdot \sin(x) $$
#
# Use `numpy` to generate `x` values from 0 to 10π and plot the result using `matplotlib`. Include the appropriate axis labels, highlight the y = 0 line, add a legend and a title.

# %%
#Import Libraries

# %%
#Set up the x and y axes

# %%
#Plot the figure

# %% [markdown]
# ## Question 2: Find the Local Maxima and Minima (10 pts)
# - Use numpy 'diff', 'sign', and 'where' functions to calculate the local maxima and minima (and the associated indices) of the damped wave in problem #1.
# - Use the indices to plot the **local** maxima and minima directly on the figure in problem #1 (there should be 5 local maxima and 5 local minima). You can use any symbols you want - but make sure that the maxima have one color and the minima another. Add a legend (important!).

# %% [markdown]
# ![Screenshot 2025-09-25 at 4.16.08 PM.png](attachment:7a8c75b7-0011-4ed2-b680-d91c571796ed.png)

# %%
#Use numpy to calculate the difference


#Use numpy to find the sign of the difference


#Use numpy to find the difference of the sign (detects sign changes)



#Find the indices of the local maxima: sign change from +1 to -1 → sign_change = -2


#Find the indices of the local minima: sign change from -1 to +1 → sign_change = 2


# Extract coordinate indices

# %%
#Plot the figure

# %% [markdown]
# ## Question 3: Sine Wave Composition with a For Loop (10 pts)
#
# Use a `for` loop to generate a **4-panel vertically stacked plot**:
# - **Panels 1–3**: Plot [0,2$\pi$] individual sine waves with wave numbers equal to (1, 2, 3), i.e. `sin(x)`, `sin(2x)`, and `sin(3x)`. The top three figures should be generated using a for loop.
# - **Panel 4**: Plot the **sum** of all three sine waves. This is the bottom panel.
#
# Label each subplot appropriately and use `matplotlib`'s `subplots()` function with `sharex=True`.

# %%
#Import Libraries

# %%
#Define the x axis (use np.linspace, and 500 pts)


#Define the y values of the first three sinusoids. Hint: These should be stored in a single
#numpy array so that you can embed them in a for loop.


#Define your y value of the 4th panel

# %% [markdown]
# ## Question 4: Points in Common (10 pts Extra Credit!)
# - Use numpy to generate three different sine waves from [0, 2$\pi$] with wave numbers(1, 2, and 3).
# - Use numpy to calculate the differences between each of these curves.
# - Identify where the three curves intersect. HINT: The most straight-forward way to do this is to compare them using a logical statement embedded within the numpy 'where' command.
# - Add the intersection points on the along with the three sinusoids and hand in **one properly annotated figure**. Feel free to use whatever symbol makes you happy.

# %%
#Define the x axis (use np.linspace, and a 1000 pts)


#Define the y values of the three sinusoids


#Calculate the differences for each of the sinusoid pairs


#Identify points where all differences are below a user-specified threshold
#(they won't be zero - I used 0.025)


#Extract the x and y values of the intersection points - you will need these
#in order to plot them!

# %%
#Plot the sinusoids and the intersection points.
