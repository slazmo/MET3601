# %% [markdown]
# ### HoHoHo-dographs

# %%
from metpy.units import pandas_dataframe_to_unit_arrays, units
import matplotlib.pyplot as plt
from metpy.plots import SkewT
from metpy.plots import Hodograph
import metpy.calc as mpcalc
from metpy.plots import colortables
import numpy as np
from siphon.simplewebservice.wyoming import WyomingUpperAir
# %matplotlib inline

# %%
# Create a datetime for our request - notice the times are from laregest (year) to smallest (hour)
from datetime import datetime
request_time = datetime(2023, 4, 1, 0)

# %%
# Store the station name in a variable for flexibility and clarity
station = 'ILX'

# %% [markdown]
# ![Screenshot 2025-11-12 at 9.38.34 AM.png](attachment:5ab24533-be0c-4eb0-9c21-229aacd63934.png)

# %%
# Import the Wyoming simple web service and request the data
df = WyomingUpperAir.request_data(request_time, station)

# %%
#Dump the header

# %%
#Check on the units

# %%
#Let's remove (trim) winds above 6 km here

# %%
#Plotting time 
#fig, ax = plt.subplots(1, 1, figsize=(8, 8))
