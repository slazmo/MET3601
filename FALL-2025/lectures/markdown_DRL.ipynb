# %% [markdown]
# ### Insert Course Home Page
# ![Screenshot 2025-08-18 at 11.41.38 AM.png](attachment:4334cd42-4afa-47e9-8f35-8e528a6ca15f.png)

# %%
print ('this hurts my brain')
# Out:
# this hurts my brain

# %% [markdown]
# ### The JupyterLab Tabs(in the cloud) look something like this...
#
# ![Screenshot 2025-08-18 at 9.09.46 AM.png](attachment:cb6f2d71-9bd7-405d-8ab3-b2dc4dbda475.png)

# %% [markdown]
# ### File Tab

# %% [markdown]
# ### Edit (cell operations)

# %% [markdown]
# ### View
# ##### Show Line #s

# %% [markdown]
# ### Run Tab

# %% [markdown]
# ### The Kernel
# ![Screenshot 2025-08-18 at 9.22.03 AM.png](attachment:499267ce-9d8b-4ecc-8d44-c03a1584f355.png)

# %% [markdown]
# ### Settings
# ##### Theme

# %% [raw]
# Style

# %% [markdown]
# Flee!

# %% [raw]
# Size

# %% [markdown]
# # Flee!
# ## Flee!
# ### Flee!
# #### Flee!
# ##### Flee!
# ###### Flee!

# %% [raw]
# Italics, Italics+Fontsize

# %% [markdown]
# *Flee!*
#
# ##### *Flee!*

# %% [raw]
# Bold, Bold+Fontsize

# %% [markdown]
# This is my last time to **Flee!**

# %% [raw]
# Create a Link [name](https...)

# %% [markdown]
# [CRS](https://research.fit.edu/center-for-resilience-science/)

# %% [raw]
# Create a Link (cut and paste)

# %% [markdown]
# https://research.fit.edu/center-for-resilience-science/

# %% [raw]
# Create a bulleted list

# %% [markdown]
# - List1
# - List2
# - List3

# %% [raw]
# Block Quote Text (vertical)

# %% [markdown]
# >Flee!

# %% [raw]
# Block Quote Text (horizontal)

# %% [markdown]
# Flee!
#
# ---

# %% [markdown]
# ## Latex
#
# # AI
# ## *How do I write an equation in markdown?*
#
# ## $$ E = mc^2 $$
#
# ## $ E = mc^2 $

# %% [markdown]
# ### [GeeksforGeeks](https://www.geeksforgeeks.org/machine-learning/markdown-cell-in-jupyter-notebook/)

# %% [markdown]
# # Inline use
#   I am a math geek, flee! $e^{i\pi} + 1 = 0$

# %% [markdown]
# ## Equations on their own line... use '$$'
#
# This equation is more complicated, flee!
#
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$
