# %% [markdown]
# ## Assignment #6
#
# This assignment can be completed by adding code to this notebook for each question.
#
# Turn in a completed script, renamed as
#
# `assignment6_lastname.ipynb`
#
# via JupyterHub and Canvas.
#
# **DUE DATE: 12 November 2025 at 11 a.m.**
#
# Prior to turning in your script, please cleanup and comment your code for each problem. Be sure that your output is self-describing.

# %%
from datetime import datetime

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Question
# (50 points) Climo graph of maximum temperature and accumulated precipitation for New York City, NY (sid= `nycthr`).
#
# Data Link: http://data.rcc-acis.org/StnData?sid=nycthr&sdate=por&edate=por&elems=mint,avgt,maxt,pcpn,snow,snwd&output=csv
#
# Complete the following tasks
#
# 1. (5 points) Create a 30 year mean (using data from 1 January 1991 to 31 December 2020) for each day (using Pandas groupby method) for the **maximum** temperature and precipitation.
# 2. (5 points) Tansform the 30-year mean accumulated precipitation into a cumulative sum of precipitation (e.g., adding all of the previous days of the year precipitation to the current day so that at the last day of the year reflects the total accumulated precipitation for that time period).
# 3. (5 points) Subset and create a new variable that contains the temperature data for 2024.
# 4. (5 points) Subset and create a new variable that contains the acuumulated precipitation data for 2024.
# 5. (10 points) Plot the 30-year mean temperature average along with the data for 2024 on a single axis. Set your x-axis values to be Julian day of the year (e.g., 1-366, may need to be less for current year data)
# 6. (10 points) Plot the 30-year mean accumulated precipitation along with the data for 2024. Again set your x-axis values to be Julian day of the year (e.g., 1-366, may need to be less for current year data).
# 7. (10 points) Appropriately title, label, and have good plot aesthetics for your figure.
# 8. Save your figure with an appropriate name.
#
# Notes:
# * You should have two figures at the end one plotting the temperature data, the other plotting the precipitation data.
# * Use appropriate colors for all plot characteristics.
# * As an example, check out the precipitation accumulation graphics here https://www.weather.gov/wrh/climate?wfo=mlb.
#
# ![Screenshot 2025-11-02 at 3.03.02 PM.png](attachment:4be73c3c-b662-45e2-b496-3bddc6a14778.png)
