# %% [markdown]
# ## Plotting Timeseries
#
# One of the main plotting libraries that is widely used within the atmospheric sciences is [matplotlib](https://matplotlib.org). This is a robust library that contains a miriad of options for plotting many different types of data. To begin simple [line](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html#matplotlib.pyplot.plot) and [scatter](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html#matplotlib.pyplot.scatter) plots will be utilized.
#
# Matplotlib Documentation: https://matplotlib.org

# %% [markdown]
# ## Making plots with Matplotlib
#
# <span style="color:red">REF: Decaria Sections 10.1-10.7</span>
#
# Previously we used a Python module to help us in creating and using arrays called Numpy. Now we desire to use a different module to create plots using Python. The most common module is matplotlib, which is based on Matlab plotting techniques. We will first create a plot using simple examples and work our way up to using values stored in arrays and plotting them.
#
# There is plenty of online documentation for matplotlib and it can be found at http://matplotlib.org/, specifically there are a lot of examples of various types of plots and those are located at http://matplotlib.org/gallery.html .
#
# The way to really learn Python, or any computing language is to just do. Find examples, or create examples for yourself and make changes like adding a title. Some common functions of pyplot functions and methods:
#
# <span style="font-family:Courier">plt.figure &nbsp;&nbsp;&nbsp;</span> set figure numbers for making multiple figures in one script <br>
# <span style="font-family:Courier">plt.plot &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span> set figure numbers for making multiple figures in one script <br>
# <span style="font-family:Courier">plt.title	&nbsp;&nbsp;&nbsp;&nbsp;</span> put a title on the figure <br>
# <span style="font-family:Courier">plt.text &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</span> add text to the figure at a specified location <br>

# %%
# Import Libraries

# %% [markdown]
# ## Basic Line Plot
#
# In this course we will use the basic `pyplot` module (which we brought in with the alias `plt`) from the Matplotlib library to make our plots. The main plotting function from this module is
#
# ```python
# plt.plot(x, y)
# ```
#
# The way that this function works is by plotting the horizontal (x-axis) variable by the vertical (y-axis) variable.
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %%
#Create x, y coordinate values
x = 
y = 

#Diagnostics


#Draw plot


#Add hz line at zero


#Add second plot
# Out:
#   Cell In[1], line 2
#     x =
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Multiple Line Plots
# Each axes can have multiple plots added to them by simply making multiple calls of the plot method. When adding multiple lines, it is imperative to change the features of how the data are plotted to keep them all distinct.
#
# When you introduce more than one line on a plot, it will be necessary to include a legend to describe what each line represents. This is most easily accomplished by adding the label keyword to the plot method and then calling `ax.legend()` to have a legend placed in a  default location on your plot.

# %% [markdown]
# ## Defining a Figure
#
# Creating an image with Matplotlib begins with the idea of the figure. The figure is the entire image entity. Within a fiugre you can have one or more axes where data will be plotted using the ordinate data (commonly x-axis) axis and abscisssa data axis (commonly y-axis).
#
# ![](https://files.realpython.com/media/fig_map.bc8c7cabd823.png)
#
# https://files.realpython.com/media/fig_map.bc8c7cabd823.png
#
# It is best to define a specific axes for plotting and use the methods off of that object to set all of your plotting parameters.
#
# There are a number of ways to define a plotting axes, but one simple method is to create a figure subplot with
#
# ```python
# ax = plt.subplot(111)
# ```
#
# This will create a plotting axis in a single figure that occupies one row and one column. We'll talk about ways to have multiple axes in future lectures.
#
# Then, to plot, use a method with the axes object
#
# ```python
# ax.plot(x, y)
# ```
#
# This works the same way as the `plt.plot` function, but is now a method off of the axes and is considered the more robust way to use Matplotlib for plotting.

# %%
#Create Subplots

#Add labels


#Save Figure

# %% [markdown]
# ## Modifying Plot/Figure Characteristics
#
# There are many ways to modify your plot to better illustrate your data. Here are some of the common keywords that you can add to any lineplot (and many other types of plots):
#
# * `color`
#    - This attribute controls the color of your lineplot. There are a number of named colors available in Matplotlib and can be found at https://matplotlib.org/stable/gallery/color/named_colors.html. In addition, you can use any HTML hex color code as a string color name.
# * `linestyle`
#    - This attribute controls the type of line that is plotted. The options are 'solid', 'dashed', 'dotted', and 'dashdot'. There are other linestyle types and we you can find all of the options at https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html
# * `linewidth`
#    - This attribute controls the thickness of the line being plotted and is set using a integer or float value.
# * `alpha`
#    - This attribute controls the transparency of the line being plotted. It should be set with a floating point value where 0 would be completely transparent and 1 is no transparency.
# * `label`
#    - This attribute stores a name for the line being plotted, which can be used with plotting a legend.
# * `marker`
#    - This attribute will plot a marker at each point that defines the line being plotted. Additional attributes exist to control the marker size, edgecolor, facecolor, etc.

# %% [markdown]
# ## Saving Figures
# An important part of creating figures is saving them to use in other contexts, such as a paper or presentation. The pyplot function to save a figure is:
#
# ```python
# plt.savefig('figname.png', dpi=150, bbox_inches='tight')
# ```
#
# savefig documentation: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html
#
# The most common format to save your image is a `png`, which stands for portable network graphic, but there are other options including `pdf`, `svg`, `eps`, and `ps`. To save your figure in a particular format, just use the extension on your filename associated with the particular format type. In addition, there are a number of keyword arguments that can be set to alter the look of the saved image. The two that you should commonly use are the `dpi` (dots per inch) setting and `bbox_inches` setting to get rid of excess space surrounding the figure being saved.

# %% [markdown]
# ### Matplotlib Image Options
# <img src="attachment:e5b4d95d-84ef-4635-b4c1-152e759f4f70.png" width="75%">

# %% [markdown]
# See Below...This is for the vertically stacked images
# ![Screenshot 2025-09-23 at 1.14.38 PM.png](attachment:f10d9dd8-6f97-440c-abb0-3a33b2ddaa55.png)

# %% [markdown]
# Matplotlib uses inches as its native standard unit
#
# Depending on your monitor's resolution and DPI (dots per inch) settings, 6 inches in Matplotlib code might not exactly match 6 inches when you hold a physical ruler up to your monitor. However, it maintains that specific 6:4 (or 3:2) aspect ratio.

# %%
# Create a figure with two subplots side by side or stacked


# First subplot


# Second subplot


# Adjust layout and display the plots

# %%
# Image diagnostics

# %% [markdown]
# ![Screenshot 2025-09-23 at 1.23.34 PM.png](attachment:ea9c0289-6653-4d14-853b-8795a8eafa25.png)
#
# ## Note Also:
# ### 0.844954 (Width): The subplot takes up 84.5% of the total figure width.0.308299 (Height): The subplot takes up 30.8% of the total figure height.Because your code calls plt.With tight_layout(), Matplotlib automatically shrinks these dimensions from their default values to make room for the labels, titles, and ticks so they don't overlap.

# %% [markdown]
# ## Axes Settings
# Often the default settings are just fine in plotting your data, but there are further methods for refining your plot image.
#
# For example, in the figure we created above there are no labels for the x- and y-axis data. It is important to always properly label each axis and add a title to each axes. This helps anyone who is viewing your figure within a paper or presentation. Additionally, you may need or want to set different limits of your data axis.
# * `ax.set_ylabel`
#    - This attribute sets the text label of the y-axis.
# * `ax.set_xlabel`
#    - This attribute sets the text label of the x-axis.
# * `ax.set_title`
#    - This attribute sets the text that you want to title the axes plot.
# * `ax.set_ylim`
#    - This attribute uses a minimum and maximum value to set the limites of the y-axis.
# * `ax.set_xlim`
#    - This attribute uses a minimum and maximum value to set the limites of the x-axis.

# %%
#From previous figure - no subplot (no ax object)

# %%
#Try with subplot

# %% [markdown]
# ## Read Data and Plot
# Let's do an example that reads in some data then plots
#
# Let's use some weather data from O'Hare International Airport, available from the RCC ACIS website. This data has been slightly modified for ease of use including adding an additional header line, and converting trace precipitation, T, to a numeric value, 0.0001.
#
# http://data.rcc-acis.org/StnData?sid=KORD&sdate=2010-01-01&edate=2010-12-31&elems=mint,avgt,maxt,pcpn,snow,snwd&output=csv
#
# The FAA has a point and click map access to ASOS/AWOS station names:
# https://www.faa.gov/air_traffic/weather/asos
#
# ![Screenshot 2026-08-16 at 11.48.22 AM.png](attachment:62cbe765-34a7-4650-873b-f77c20a82daf.png)

# %% [markdown]
# ### Example: Create your own data pull for a different location (2025, Tallahassee )
# http://data.rcc-acis.org/StnData?sid=KTLH&sdate=2025-01-01&edate=2025-12-31&elems=mint,avgt,maxt,pcpn,snow,snwd&output=csv
#
# *You can click on the link above and download the data yourself!*

# %%
#Set the path and filenames
path  = ''
file  = 'ord_2010_data.csv'
file2 = 'tlh_2025_data.csv'  

#Use Linux to dump the top N lines of a file
# !head -10 "{path}{file}"  
print()
# !tail -10 "{path}{file}"  
print()
# Compare with TLH (2025)
# !head -10 "{path}{file2}"  
print()
# !tail -10 "{path}{file2}"

# %% [markdown]
# FYI, looks like ACIS server is returning two different CSV formats - so if you opt to go with a different station other than my example, then you can add the second row to the .csv. There is a better way to do this, but...
#
# Need to skip the first two header rows, and the dates are going to be problematic to read in using Numpy due to the dashes. We can use a keyword (`usecols`) to avoid reading in that column by specifying only the columns that we want. Let's read only the data for the maximum, average, and minimum temperatures (columns 1, 2, and 3).

# %% [markdown]
# ```Python
# #                                         mint, avgt, maxt col indices
# ord_data = np.loadtxt(path+file, skiprows=2, usecols=[1,2,3], delimiter=',')
# ```

# %%
#Read the ORD data (copy and paste from above)

# %%
#Diagnostic

# %%
#Print ord_data

#Diagnostics

# %%
#Extract the avg. temperature only


#Diagnostis

# %% [markdown]
# ### Now let's set up a new array for days using just the integer days ("day of the year"), and for 2010, there were 365 days in the year.

# %%
#Use the numpy method 'arrange' to create a day of the year array

# %% [markdown]
# ## Exercise #1
#
# Starting with the Matplotlib examples, create figur with the minimum and maximum temperatures in different colors. Additionally, add axis labels and a title that accurately describes the plotted data.
#
# ```Python
# plt.figure(4, figsize=(8,8))
# ax4 = plt.subplot(111)
# ax4.plot(days,avg_temp)
# plt.show()
# ```

# %%
#Add plot here (copy and paste above)

# %%
#Let's pull min temp from ORD

# %%
#Plot both min and max temperature

# %% [markdown]
# ### Accoutrements
# ```Python
# ax4.set_title('KORD Average Temperature (°F)')
# ax4.set_ylabel('Temperature (°F)')
# ax4.set_xlabel('Day of year in 2010')
# ```

# %%
#Add some more goodies

plt.figure(4, figsize=(8,8))
ax4 = plt.subplot(111)

ax4.plot(days,avg_temp, color='tab:red',label="avg_temp")
ax4.plot(days,min_temp, color='tab:blue',label = "min_temp")
#ax4.plot(days,avg_temp, color='tab:red',linestyle ='-.')  #try '--'

#Add title and labels (copy and paste from above)


#Add these later


#plt.axhline(y=0)
ax4.axhline(y=32,linestyle='--',color= 'black')

#add legend


plt.savefig('ord_avg_temp_2010.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 #Add some more goodies
# ----> 3 plt.figure(4, figsize=(8,8))
#       4 ax4 = plt.subplot(111)
#       6 ax4.plot(days,avg_temp, color='tab:red',label="avg_temp")
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Exercise #2
# On which day was there the greatest range in temperature between the maximum and minimum temperatures? On which day was there the smallest range between the maximum and minimum temperatures?

# %%
#Need to read in the max temp

# %%
#Print min temperature

# %%
#Create new difference arrays, but first check dimensions and type!

# %%
#Print diurnal range array and shape
# Out:
# (365,)
# [11.  9. 19. 11. 10. 10.  6. 16. 16. 18. 11. 11. 16.  9.  9.  4. 10.  4.
#  11.  9.  5.  2. 10. 16. 13. 12. 14. 11. 16.  7. 14. 16.  7.  9. 12.  5.
#   6.  8. 10.  5.  9. 20. 22. 19. 20. 22.  7.  6. 14. 23.  9.  3.  4. 11.
#   8. 10. 14.  6.  6.  9. 10. 15. 20. 15. 25. 20. 11. 19. 16. 16. 15.  4.
#  10.  9. 26. 31. 20. 26.  8.  9. 15. 31. 18. 18. 14. 19. 15. 16. 35. 26.
#  29. 22. 10. 37. 22. 29. 12.  6. 26. 36. 19. 26. 15. 34. 21. 29. 22. 16.
#  21. 26. 21. 22. 22.  9. 13. 16. 14. 31. 33. 19. 12. 16. 22. 29. 16. 17.
#  14.  8. 20. 17.  8.  7. 25. 19. 18. 25.  8. 19. 30. 27. 17. 16. 27. 21.
#  19. 21. 16. 22. 27. 30. 15. 22. 20. 15. 26. 19. 21. 16.  9. 18. 19. 25.
#  15.  9. 10. 19. 19. 20. 23. 19. 17. 18. 16. 18. 19. 22. 18. 13. 19. 16.
#  19. 22. 24. 27. 23. 13. 17. 22. 15. 18. 20. 19. 19. 14. 20. 19. 23. 22.
#  20. 15. 18. 19. 21. 24. 18. 15. 23. 20. 15. 15. 11. 15. 21. 17. 20. 12.
#  15. 18. 21. 18. 16. 14. 15. 18. 19. 16. 17. 17. 15. 21. 22. 21. 15. 13.
#  15. 20. 18. 20. 27. 23. 23. 14. 18. 10. 18. 14. 17. 27. 16. 19. 20. 17.
#  17. 17. 29. 25. 23. 16. 16. 25.  7. 12. 13. 20. 11. 24. 24.  8. 10. 17.
#  25. 23. 22. 25. 12. 14. 22. 29. 32. 27. 31. 31. 27. 28. 24. 19. 23. 19.
#  31. 18. 18. 21. 26. 18. 31. 11. 18. 16. 16. 22.  7. 19. 21. 16. 22. 20.
#  23. 13. 12. 21. 24. 29. 29. 25. 21.  8. 18. 11. 19. 18. 10. 13. 26. 13.
#  19. 28. 13. 15. 18. 14. 13. 24. 16. 24.  4. 11. 13.  9. 14. 12.  9. 18.
#  24. 14. 12. 19.  9. 15. 23.  7.  9.  9. 13. 21.  5. 17. 10.  5. 11. 14.
#  11. 15. 27. 12. 12.]

# %%
#Find the max and min diurnals


#print(f'The minimum and maximum temperature differences are {?} and {?} respectively 😯')

# %% [markdown]
# ### Numpy where method
#
# ```Python
# imax = np.where(dif_tmp == dif_tmp.max())#[0][0]
# imin = np.where(dif_tmp == dif_tmp.min())#[0][0]
# ```

# %%
#Use the numpy method 'where' to find the indices in the dif_tmp array where the min/max are
#Note that np.where() returns a tuple with one array: 

#(array([index])[0][0] extracts the first (and usually only) index from that array

# %% [markdown]
# ### Some f-strings
# ```Python
# print(f'The maximum difference {?} is at array index {?}')
# print(f'The minimum difference {?} is at array index {?}')
# ```

# %%
#Use the returned values in the cell above to print the differences (copy and paste from above)

# %%
#Which days (day #) are these?

# %% [markdown]
# ### You can convert a day number (1–365) from a specific year like 2010 into a proper date using Python’s datetime module.  Coming!
