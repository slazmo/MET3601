# %% [markdown]
# <div style="text-align:center; line-height:1.0;">
#     <span style="font-size:32px; font-weight:bold;">F-Strings and Command Line Input</span><br>
#     <span style="font-size:24px;">MET 3601</span><br>
#     <span style="font-size:20px;">Dr. Steven Lazarus</span><br>
# </span><br>
# </div>

# %%
# Place Python libraries here if needed

# %% [markdown]
# ## Code Comments
#
# It is imperative that you comment your code to ensure you remember what pieces of your code are doing. This will help when you come back to old code after a period of time or share your code with someone else. Comments can be made in two primary ways, through stand alone comments on one line or inline, either way you want to use the special character `#`, which is officially known as an octothorp or better known to you as a hashtag.
#
# Any line that starts with a `#` will not be executed at runtime. Any line that has a `#` in it, nothing will be executed after that symbol.
#
# ```python
# # This is a comment and won't be executed
# # The following line is executable code
# print('Hello') # this is an inline comment
# ```
#
# Output
# ```python
# Hello
# ```

# %% [markdown]
# ## Who are you?

# %%
fullname  =
# Out:
# Input your full name:  Steven Lazarus

# %%
fit_major =
# Out:
# What is your major?  Meteorology

# %%
home_town =
# Out:
# What is your Hometown and State?  Hollywood, Florida

# %%
fave_musician =
# Out:
# What is your favorite musician/group?  Avett Brothers

# %%
fave_book =
# Out:
# What is your favorite book?  A Confederacy of Dunces

# %%
fave_movie =
# Out:
# What is your favorite movie?  Grand Budapest Hotel

# %%
# Print them out (tuple)
fullname, fit_major, home_town,fave_musician, fave_book, fave_movie
# Out:
# ('Steven Lazarus',
#  'Meteorology',
#  'Hollywood, Florida',
#  'Avett Brothers',
#  'A Confederacy of Dunces',
#  'Grand Budapest Hotel')

# %%
#Save the info in a variable (this is a tuple)

# %%
# Easier way to output the tuple

# %%
# Diagnostics (type,len, and indexing)

# %% [markdown]
# ### For more on unicode emojis see https://www.geeksforgeeks.org/python-program-to-print-emojis/

# %%
# Combine all inputs into a short paragraph

emoji = "\U0001f600"  #For more see above link

print(f'{fullname} is a {---} major from {---}. My favorite musician(s) are the {---} but that ' 
      f'might depend on the day {---}. {---} has particular (peculiar?) tastes in literature '
      f'- but one the alltime favorite is the {-}. Note however '
      f'that my favorite movie is The {---}🍿!')

# %% [markdown]
# ![Screenshot 2026-08-19 at 8.19.03 AM.png](attachment:0ac49a27-3dca-47ca-87e6-a9ad79d88318.png)
