# %% [markdown]
# <div style="text-align:center; line-height:1.0;">
#     <span style="font-size:32px; font-weight:bold;">Linux Basics</span><br>
#     <span style="font-size:24px;">MET 3601</span><br>
#     <span style="font-size:20px;">Dr. Steven Lazarus</span><br>
# </span><br>
# </div>

# %%
# Place Python libraries here if needed

# %% [markdown]
# # Navigating the Linux side of things
#
#
# ## Useful Linux commands
#
# - ### The following can be typed on the command line (after the prompt) in a Linux shell and do not *necessarily* need any inputs
#
# ```python
# ls,  pwd, date
# ```
# - ### You can also run these directly in the notebook! These require at least some nominal input and must be preceded by either a '!' or '%'
#
# ```python
# cat (more), cp, cd
# #For example, you might want to move around in your notebook, rename a file, or expose file contents)
# ```
#
# - ### You can inspect the beginning and end of data/text files such as .csv and .txt
#
# ```python
# tail, head
# ```

# %%
#Examples
