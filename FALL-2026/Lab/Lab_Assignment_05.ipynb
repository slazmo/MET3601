# %% [markdown]
# <div style="text-align:center; line-height:1.0;">
#     <span style="font-size:32px; font-weight:bold;">Computational Techniques for Meteorology Lab</span><br>
#     <span style="font-size:24px;">MET 3602 (ENS 4901 Section 2)</span><br>
#     <span style="font-size:20px;">Dr. Steven Lazarus</span><br>
#     <span style="font-size:20px;">Link 332</span><br>
#     <span style="font-size:20px;">Dr. L Office Hours: T/Th 10:00-11:30 a.m.</span><br>
#     <span style="font-size:20px;">Trey Rockey Office Hours: M 12:30-2:30 p.m. & T 10:00 a.m.-12:00 p.m.</span><br>
# </div>

# %% [markdown]
# ## Instructions
#
# - Answer all questions and place answers in the code cells provided and ensure all outputs are displayed.
#
# - Save (**rename**) the notebook as `Lab_Assignment_05_lastname.ipynb` and submit to Canvas by 10:00 a.m., Friday, Sept. 25.

# %% [markdown]
# ### Learning Objectives
#
# By the end of this lab, you will be able to:
#
# - Import and inspect a climatological dataset using Linux commands and NumPy file I/O functions.
#
# - Reshape and organize time-series data into a two-dimensional year-by-month array for efficient analysis.
#
# - Use dictionaries and array indexing techniques to extract ONI values for specific months and years.
#
# - Compute and interpret descriptive statistics (mean, median, and standard deviation) across both monthly and yearly dimensions of the ONI record.
#
# - Identify and interpret ENSO extremes by determining the timing and magnitude of the strongest El Niño and La Niña events in the dataset.
#
# - These align closely with the programming skills and meteorological interpretation emphasized throughout the assignment.

# %% [markdown]
# # 🌊 Week 6 Lab: ONI, The Official ENSO Index <span style="color:red">  35 pts</span>
#
# In this lab, you'll explore the El Niño–Southern Oscillation using the ONI index. The dataset contains monthly ONI values from 1950 to 2026.
#
# **Notes:**
# The ONI was pulled from the Physical Sciences Laboratory at  https://psl.noaa.gov/data/timeseries/month/DS/ONI/.
#
# The Oceanic Niño Index (ONI) is a rolling 3-month average sea surface temperature (SST) anomaly in the east-central tropical Pacific (specifically the Niño 3.4 region spanning 5°N–5°S, 120°W–170°W), used by NOAA to monitor the El Niño-Southern Oscillation (ENSO) cycle. For more on the ONI see: https://www.climate.gov/news-features/understanding-climate/climate-variability-oceanic-nino-index.
#
# Make sure documentation (e.g., comment block and comments throughout code) is present in your source code

# %%
import numpy as np

# %% [markdown]
# ## Question 1: Investigate 🕵️ the dataset  <span style="color:red">  3 pts</span>
# **a.** Use the relevant Linux command to pull the number of lines from the data
# **b.** Use the relevant Linux command to print the header
# **c.** Use the information in a) and b) to open the data set with the numpy loadxt function and print the contents to the screen. You will need to read the dates in separate from the data (i.e., two calls to loadtxt).

# %%
#a.) Linux word count command


#b.) Print header




#c.) 

path = ''
file = 'oni.txt'   #'oni_monthly.txt'

#Read in the data

#Read in the dates

# %% [markdown]
# # Question 2: Extraction <span style="color:red">  10 pts</span>
# **a.** Reshape the data (into a 2d array) so that the 12 months span the columns and years in the rows.
# **b.** Extract all 12 monthly ONI values for a given **input** year.
# **c.** Create a dictionary that assigns a 3-character month (i.e., Jan, Feb, Mar...) to a corresponding index 1-12.
# **d.** Use your answer in c.) to extract all years for a given **input** month.

# %%
#a.) Reshape the data

# %%
#b.) Extract a given year

# %%
#c.) #Create a dictionary and assign a 3-character month (e.g., Jan, Feb...) to an index 1-12

# %%
#d.) Extract all years for an input month

# %% [markdown]
# ## Question 3: Compute Statistics. <span style="color:red">  12 pts</span>
#
# **a.** Use numpy to calculate the following:
#
# - the average ONI for each month across all years.
#
# *Which months tend to show stronger ENSO signals?*
#
# - the median ONI for each month across all years.
#
# - the ONI std. dev. for each month across all years.
#
# **b.** Use a for loop and your dictionary in #2 to print out the average ONI for each month. For example:
#
# ```Python
# Month       Mean     Median    Std Dev
# #----------------------------------------
# Jan       0.0107    -0.1700     1.0332
#  :
#  :
# ```
# **c.** Calculate the same three statistics for each year and print these out.  For example:
# ```Python
# Year         Mean     Median    Std Dev
# #----------------------------------------
# 1950      -0.8600    -0.8250     0.3742
# 1951       0.4308     0.6400     0.6182
# 1952       0.1742     0.1500     0.1724
# 1953       0.7133     0.7500     0.1200
# ```

# %%
#Use the reshaped data for all of these!
#a.) Mean.

# %%
#a.) Std dev

# %%
#a.) Median

# %%
#b.)  Use the dictionary in #2 above to print the mean, median, std dev (watch out for missing values - see loadtxt!). 
#DRL For pretty formatting query AI

# %%
#c.) Calculate the stats for each year

# %%
#c.) Use numpy to create a list of years
#DRL For pretty formatting query AI

# %% [markdown]
# ## Question 4: ONI Extremes <span style="color:red">  10 pts</span>
#
# **a.** Find the year and month with the highest ONI.
# *Was this a strong El Niño year?*
#
# **b.** Find the year and month with the lowest  ONI.
# *Was this a strong La Niño year?*

# %%
#a.) Find/print the month/year with the max ONI

# %%
#b.) #a.) Find/print the month/year with the min ONI 

#DRL  Use this list, it is easier than accessing the dictionary!
month_names = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

# %% [markdown]
# *Was this a strong La Niño year?*
