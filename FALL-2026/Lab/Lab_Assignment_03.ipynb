# %% [markdown]
# <div style="text-align:center; line-height:1.0;">
#     <span style="font-size:32px; font-weight:bold;">Computational Techniques for Meteorology Lab</span><br>
#     <span style="font-size:24px;">MET 3602 (ENS 4901 Section 2)</span><br>
#     <span style="font-size:20px;">Dr. Steven Lazarus</span><br>
#     <span style="font-size:20px;">Link 332</span><br>
#     <span style="font-size:20px;">Dr. L Office Hours: T/Th 10:00-11:30 a.m.</span><br>
#     <span style="font-size:20px;">Trey Rockey Office Hours: M 12:30-2:30 p.m. & T 10:00 a.m.-12:00 p.m.</span><br>
# </div>

# %% [markdown]
# ## Instructions
#
# - Answer all questions and place answers in the code cells provided and ensure all outputs are displayed.
#
# - Save (**rename**) the notebook as `Lab_Assignment_03_lastname.ipynb` and submit to Canvas before leaving class at 12:00 p.m.

# %% [markdown]
# ## 🔬 Week 3 Lab: Dictionary not Pictionary <span style="color:red">30 pts</span>

# %% [markdown]
# **Learning Objectives:**
# - Learn how sets work and how to perform set operations.
# - Understand dictionary creation, access, and manipulation.
# - Practice conditional logic using `if`, `elif`, and `else`.

# %% [markdown]
# ## Question 1: Working with Dictionaries <span style="color:red">10 pts</span>

# %% [markdown]
# **a.)** Weather Dictionary
# Create a dictionary named `weather_data` with keys: `'temperature'`, `'humidity'`, and `'wind_speed'`. Assign each key a list of 5 values. **3 pts**

# %% [markdown]
# **b.)** Access and Modify **3 pts**
# - Print the values associated with `'humidity'`.
# - Add a new key `'pressure'` with a list of 5 values.
# - Use the methods `.keys()` and `.values()` to display all keys and values.

# %% [markdown]
# **c.)** Write a definition that takes a dictionary and a key, and returns the average of the values associated with that key. **4 pts**

# %% [markdown]
# ## Question 2: Exploring Sets <span style="color:red">12 pts</span>

# %% [markdown]
# **a.)** Create two distinct lists that are comprised of the hurricane names from the 2012 and 2018 seasons (visit NHC or use an AI engine), respectively. Convert it to a set and print the result. Use Google to get the names for these two seasons. **2 pts**

# %%
#a)

# %% [markdown]
# **b.)** Print the following **3 pts**:
# - The intersection of the two sets.
# - The union of the two sets.
# - The difference between the sets.
#
# **c.)** Print the length (# of elements) of each set above (in a and b) **2 pts**.
#
# **d.)** Use your output above to answer the following questions. **2 pts**
#
# *Are the two seasons similar? Explain briefly (visit the NHC to explain your answer!)*
#
#
# *Which, if any, storm names were retired?*
#
# **e.)** Write a definition that takes two lists and returns a set of common elements. **3 pts**

# %%
#b)


#c)


#d)

# %%
#e) Write a definition...

# %% [markdown]
# ## Question 3: NumPy Arrays <span style="color:red">3 pts</span>
# **Objective:** Use NumPy to create and manipulate arrays.

# %% [markdown]
# **a.)** Create a *3 x 3* 2D NumPy array and calculate the mean of each row and column. Check the dimensions using the 'ndim' function in the numpy library! Also print out the `size` and `shape`.

# %%
# a)

# %% [markdown]
# ## Question 4: (Out of?) Control Flow - If Statements and Indexing<span style="color:red">  5 pts</span>

# %% [markdown]
# **a.)** Convert your 2012 hurricane set above back to a list and print it out. **2 pts**
#
# **b.)** Use the 'input' command to check whether there is a hurricane in the list that begins or ends with the input character. If there isn't, then indicate this in a print statement and if there are then indicate how many end with that letter. Use `f-string` formatting for your print statements. **3 pts**
#
# **Hint:** You will need to remove the case sensitivty of your input (i.e., use the `lower` or `upper` methods)!

# %%
# a)

# %%
# b)
