# %% [markdown]
# <div style="text-align:center; line-height:1.0;">
#     <span style="font-size:32px; font-weight:bold;">Computational Techniques for Meteorology Lab</span><br>
#     <span style="font-size:24px;">MET 3602 (ENS 4901 Section 2)</span><br>
#     <span style="font-size:20px;">Dr. Steven Lazarus</span><br>
#     <span style="font-size:20px;">Link 332</span><br>
#     <span style="font-size:20px;">Dr. L Office Hours: T/Th 10:00-11:30 a.m.</span><br>
#     <span style="font-size:20px;">Trey Rockey Office Hours: M 12:30-2:30 p.m. & T 10:00 a.m.-12:00 p.m.</span><br>
# </div>

# %% [markdown]
# ## Instructions
#
# - Answer all questions and place answers in the code cells provided and ensure all outputs are displayed.
#
#
# - Save (**rename**) the notebook as `Lab_Assignment_00_lastname.ipynb` and submit to Canvas before leaving class at 12:00 p.m.

# %% [markdown]
# ### These will be the most useful Linux Commands for this Lab (see cheat sheet and AI engines for more help!)
# ![Screenshot 2026-08-21 at 8.50.13 AM.png](attachment:c530742b-d683-47bf-ae49-a09c7e6ac77c.png)

# %% [markdown]
# # Week 1 Lab: Managing Meteorological Data with Linux and Jupyter <span style="color:red"> (25 pts)</span>
#
# ### Learning Objectives
#
# By the end of this lab you will be able to:
#
# - Navigate the Linux file system from a Jupyter notebook
# - Create and organize project directories
# - Inspect surface station climate data using Linux commands
# - Determine file size and contents
# - Search weather data files efficiently

# %% [markdown]
# ## Scenario
#
# You have received temperature datasets from several ASOS stations. Before meteorological analysis can begin, you must organize, inspect, and document the datasets. This mirrors the workflow commonly used by atmospheric scientists working with observational data.

# %% [markdown]
# ## Part 1: Explore Your Environment <span style="color:red"> (4 pts)</span>
#
# **a.** `Print the working directory`
# **b.** `List` the contents of the directory

# %%
# Answer a

# %%
# Answer b

# %% [markdown]
# ### Questions
# 1. What information does `print working directory` command provide?
#
# > Answer here
#
# 2. What information does the `list` command provide?
#
# > Answer here

# %% [markdown]
# ## Part 2: Create a Project Structure <span style="color:red"> (3 pts)</span>
#
# **a.** Use the relevant Linux command (see cheat sheet) to `make` the following directory (folders): **week1_lab/data**

# %% [markdown]
# **b.** `List` the contents of the week1_lab folder

# %% [markdown]
# ### Questions
#
# 1. What advantages does this organization provide?
#
# > Answer here

# %% [markdown]
# ## Part 3: Move Your ASOS (Files)! <span style="color:red"> (3 pts)</span>

# %% [markdown]
# **a.** Use the appropriate Linux command to `move` all of the ASOS files to the **week1_lab/data** folder.
# **b.** Use the `recursive list` option to print out the contents of the directories (folders).

# %%
# Answer a

# %% [markdown]
# ### Questions
# 1. How many datasets were provided?
#
# > Answer here
#
# 2. What stations are these and where are they located (city names)?
#
# > Answer here

# %% [markdown]
# ## Part 4: Inspect File Sizes <span style="color:red"> (3 pts)</span>

# %% [markdown]
# **a.** Use the Linux `long listing` format and `human readable file sizes` options to list the content of the week1_lab/data folder

# %%
# Answer a

# %% [markdown]
# ### Questions
# 1. Which dataset is largest?
#
# > Answer here
#
#
# 2. Why might some stations have longer records?
#
# > Answer here

# %% [markdown]
# ## Part 5: Examine the Beginning of a File<span style="color:red"> (3 pts)</span>

# %% [markdown]
# **a.** Output the `header(s)` of the .csv files in week1_lab/data

# %%
# Answer a

# %% [markdown]
# ### Questions
# 1. What information appears in the `header` row?
#
# > Answer here
#
# 2. What variables are available?
#
# > Answer here

# %% [markdown]
# ## Part 6: Examine the End of a File <span style="color:red"> (3 pts)</span>

# %% [markdown]
# **a.** Output the `tail(s)` of the .csv files in week1_lab/data

# %%
# Answer a

# %% [markdown]
# ### Questions
# 1. What is the most recent observation date shown?
#
# > Answer Here
#
# 2. Are the records chronological?
#
# > Answer Here

# %% [markdown]
# ## Part 7: Count de Records (i.e., # of lines in each csv) <span style="color:red"> (3 pts)</span>

# %% [markdown]
# **a.** Use the Linux `word count` command to count the number of `lines` in the week1_lab/data files.

# %%
# Answer a

# %% [markdown]
# ### Questions
# 1. Which station contains the most observations?
#
# > Answer Here
#
#
# 2. Is the header being counted as an observation?
#
# > Answer Here

# %% [markdown]
# ## Part 8: Search Within Datasets <span style="color:red"> (3 pts)</span>

# %% [markdown]
# **a.** Use the Linux `global regular expression print` command to search for February 5th in the week1_lab/data files.

# %%
# Answer a

# %% [markdown]
# ### Questions
# 1. What does this Linux command do?
#
# > Answer Here
#
# 2. Why might this type of searching be useful for large meteorological datasets?
#
# > Answer Here

# %% [markdown]
# ## Part 9: Station Investigation (Extra Credit,<span style="color:red"> 5 pts</span>)

# %% [markdown]
# **a.** Run the following code segments and answer the questions below.

# %%
# Full Linux command
# !ls week1_lab/data/*.csv | cut -d'/' -f3 | cut -d'_' -f1 | sort | uniq

# %%
# Break at the pipes!
# !ls week1_lab/data/*.csv

# %%
# One pipe
# !ls week1_lab/data/*.csv | cut -d'/' -f3

# %%
# Two pipes
# !ls week1_lab/data/*.csv | cut -d'/' -f3 | cut -d'_' -f1

# %%
# Three pipes
# !ls week1_lab/data/*.csv | cut -d'/' -f3 | cut -d'_' -f1 | sort

# %%
# !ls week1_lab/data/*.csv | cut -d'/' -f3 | cut -d'_' -f1 | uniq

# %% [markdown]
# ### Explain what each part of the command is doing above.
# - pipes |
#
# > Answer Here
#
# - sorting
#
# > Answer Here
#
# - unique values
#
# > Answer Here
#
#
# - text manipulation
#
# > Answer Here
