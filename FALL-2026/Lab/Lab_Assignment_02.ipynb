# %% [markdown]
# <div style="text-align:center; line-height:1.0;">
#     <span style="font-size:32px; font-weight:bold;">Computational Techniques for Meteorology Lab</span><br>
#     <span style="font-size:24px;">MET 3602 (ENS 4901 Section 2)</span><br>
#     <span style="font-size:20px;">Dr. Steven Lazarus</span><br>
#     <span style="font-size:20px;">Link 332</span><br>
#     <span style="font-size:20px;">Dr. L Office Hours: T/Th 10:00-11:30 a.m.</span><br>
#     <span style="font-size:20px;">Trey Rockey Office Hours: M 12:30-2:30 p.m. & T 10:00 a.m.-12:00 p.m.</span><br>
# </div>

# %% [markdown]
# ## Instructions
#
# - Answer all questions and place answers in the code cells provided and ensure all outputs are displayed.
#
# - Save (**rename**) the notebook as `Lab_Assignment_02_lastname.ipynb` and submit to Canvas before leaving class at 12:00 p.m.

# %% [markdown]
# ## Week 2 Lab: Weather Weenies Unite <span style="color:red"> (20 pts)</span>
#
# ### Learning Objectives
#
# By the end of this lab, you will be able to:
# - Develop Python functions to perform meteorological calculations and unit conversions.
# - Analyze weather observations using Python lists and NumPy arrays.
# - Apply statistical and computational methods to interpret temperature variability and Cooling Degree Days (CDD).

# %% [markdown]
# ## Question 1: KMLB Temperature Analysis<span style="color:red"> (10 pts)</span>
#
# **a.** Create a list of KMLB daily maximum temperature readings (in °F) for the past week (see https://www.weather.gov/wrh/Climate?wfo=mlb)
# **b.** Write a function to:
# *Convert the list to Celsius*
# *Convert the list to Kelvin*
# **c.** Create a list of KMLB daily minimum temperature readings (in °F) for the past week.
# **d.** Calculate the difference (max-min) of the two lists and store them in a separate list.
# *Print the index of the maximum difference*
# *Use this index to print the corresponding max and min values*
# **e.** Calculate the observed daily average (in °F) temperatures for the past week.
# **f.** Calculate the climatological average (in °F) temperatures for the past week (Hint: You will need to create a 3rd list).
# **g.** Create a list of corresponding KMLB dates for the past week.
# *Use the index calculated in **d)** to print the date*
# **h.** Create a `definition` to calculate the Cooling Degree Days (CDD) for the past week.
# **i.** Calculate the sum of the CDD for the past week.

# %%
# Coding Starts Here  - use separate cells for each problem

# %% [markdown]
# ## Question 2: NumPy Arrays and Scientific Computation <span style="color:red"> (10 pts)</span>
# Note that although these problems appear to be redundant, they actually are not since they should be performed using numpy here!

# %% [markdown]
# **a.** Convert the list in problem #1 above to a numpy array.
# **b.** Use the functions defined above in **b)** to:
# *Convert the array to Celsius*
# *Convert the array to Kelvin*
# **c.** Convert the list in **c)** above to a numpy array.
# **d.** Calculate the difference (max-min) of the two arrays and store them in a separate array.
# *Print the index of the maximum difference*
# *Use this index to print the corresponding max and min values*
# **e.** Calculate the observed daily average (in °F) temperatures for the past week.
# **f.** Calculate the climatological average (in °F) temperatures for the past week.
# **g.** Convert the list in **g)** above (problem 1) to a numpy array.
# *Use the index calculated in **d)** to print the date*
# **h.** Use the definition in **h)** above (problem 1) to calculate the Cooling Degree Days(CDD) for the past week.
# **i.** Calculate the sum of the CDD for the past week.

# %%
#Import library

# %%
# Coding Starts Here  - use separate cells for each problem
