# %% [markdown]
# <div style="text-align:center; line-height:1.0;">
#     <span style="font-size:32px; font-weight:bold;">Computational Techniques for Meteorology Lab</span><br>
#     <span style="font-size:24px;">MET 3602 (ENS 4901 Section 2)</span><br>
#     <span style="font-size:20px;">Dr. Steven Lazarus</span><br>
#     <span style="font-size:20px;">Link 332</span><br>
#     <span style="font-size:20px;">Dr. L Office Hours: T/Th 10:00-11:30 a.m.</span><br>
#     <span style="font-size:20px;">Trey Rockey Office Hours: M 12:30-2:30 p.m. & T 10:00 a.m.-12:00 p.m.</span><br>
# </div>

# %% [markdown]
# ## Instructions
#
# - Answer all questions and place answers in the code cells provided and ensure all outputs are displayed.
#
#
# - Save (**rename**) the notebook as `Lab_Assignment_01_lastname.ipynb` and submit to Canvas before leaving class at 12:00 p.m.

# %% [markdown]
# ## Week 2 Lab: Meteorological & Geographic Applications <span style="color:red"> (25 pts)</span>
#
# ### Learning Objectives
#
# By the end of this lab you will be able to:
#
# - Access and modify information stored in lists and dictionaries.
# - Convert geographic coordinates to formats commonly used in meteorology and GIS applications.
# - Apply Python to calculate derived atmospheric variables, including potential temperature.
# - Interpret the physical meaning of calculated meteorological quantities.

# %% [markdown]
# ## Question 1 <span style="color:red"> (2 pts)</span>
# Given the following list, use a Python built-in function to determine how many elements it has and print it to the screen. Then print only the second and third elements of the list to the screen.

# %%
values = ['Florida Tech', 1959, 'Panthers', 1000.5, 'Everglades National Park', 1e4]

# %%
# Answer

# %% [markdown]
# ## Question 2 <span style="color:red"> (3 pts)</span>
# Using the same list from question 1, add two elements to the list: 1) your hometown and state as a string; and 2) your favorite number as a float or integer. Print the new list to the screen, then check to see if the number `42` appears in the list using the Python built-in `in` function.

# %%
# Answer

# %% [markdown]
# ## Question 3 <span style="color:red"> (5 pts)</span>
# Given the following tuple that describes FIT latitude and longitude in degrees, minutes, and seconds, convert the latitude and longitude to decimal degrees and print (to the screen via standard output) the new values along with the north, south, east, or west direction.
#
# Note: That one degree is one hour, there are 60 minutes in an hour, and 3600 seconds in an hour.
#
# `Decimal Degrees = degrees + (minutes/60) + (seconds/3600)`

# %%
fit_latitude  = ( 28,  3, 54, 'N')
fit_longitude = (-80, 37, 22, 'E')

# %% [markdown]
# ### Check your answer using the online calculator...
# https://www.fcc.gov/media/radio/dms-decimal

# %% [markdown]
# ## Question 4 <span style="color:red"> (2 pts)</span>
# If you were to attempt to reassign one of the values in the fit_latitude tuple from question #3, what would happen? Explain. Type your response below as a comment.

# %% [markdown]
# #### Answer

# %% [markdown]
# ## Question 5 <span style="color:red"> (3 pts)</span>
# (5 points) Add the following wind speeds to the dictionary below using a key of "wind". Print all of the keys of the dictionary to standard output.
#
# Wind speed values: 10, 6, 8, 14

# %%
fit_obs = {'times':[0, 6, 12, 18],
           'tmpf':[88, 90, 89, 82],
           'precip':[0, .3, 0, 0]}

# %%
# Answer

# %% [markdown]
# ## Question 6 <span style="color:red"> (10 pts)</span>
# There are a number of different calculations that meteorologists routinely encounter including potential temperature. Create Python code that will read in an input temperature in Celsius and pressure in hPa. Compute the potential temperature using the input data below, and print the original temperature in Kelvin and pressure in hPa along with the calculated potential temperature to standard output.
#
# Potential Temperature Equation:
#
# \begin{equation}
# \theta={T\left(\frac{p_0}{p}\right)}^\frac{R_d}{C_p}
# \end{equation}
#
# Where p0 is the reference pressure (typically 1000 hPa), `T` is the temperature in Kelvin at the given pressure `p` (hPa), `Rd` is the dry gas constant (287 J $K^{-1}$ $kg^{-1}$) and `Cp` is the specific heat of air (1004 J $K^{-1}$ $kg^{-1}$).
#
# **Test Case 1**
# ```
# >>>
# Enter a Temperature in Celsius:
# 20
#
# Enter a Pressure in hPa:
# 850
#
# Temperature (K): 293.14999
# Pressure (hPa): 850.00000
# Pot. Temp. (K): 307.08
# >>>
# ```
# **Test Case 2**
# ```
# >>>
# Enter a Temperature in Celsius:
# -20
#
# Enter a Pressure in hPa:
# 700
#
# Temperature (K): 253.14999
# Pressure (hPa): 700.00000
# Pot. Temp. (K): 302.52805
# >>>
# ```

# %%
# Answer

# %% [markdown]
# ### Consider the Log-p/SkewT with Test Case 1 shown.  Add Test Case 2. <span style="color:red"> (2 bonus pts!)</span>
#
# Do a screen capture and import the figure below into Powerpoint, annotate the figure (i.e., add Test Case 2), screen capture again and **replace** the figure below with your new figure!

# %% [markdown]
# ![Screenshot 2024-09-08 at 2.11.12 PM.png](attachment:8b112431-111d-4835-8c29-eff7d4fb40b5.png)
