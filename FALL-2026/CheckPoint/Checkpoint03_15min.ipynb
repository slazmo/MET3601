# %% [markdown]
# # MET 3601 <span style="color:green"> Checkpoint #3</span>, <span style="color:red"> Points: 20</span>
# ## Control Flow and Functions

# %%
from IPython.display import display, Markdown

name = input("Please enter your first and last name: ")

# Prints the name in bold green text
display(Markdown(f"### Welcome, <span style='color: green;'>**{name}**</span>!"))

# %%
from datetime import datetime

# Get current system date and time
now = datetime.now()

# %I = 12-hour hour, %M = minute, %p = AM/PM
formatted_date = now.strftime("%A, %B %d, %Y")
formatted_time = now.strftime("%I:%M %p")

print(f"Current Date: {formatted_date}")
print(f"The time is: {formatted_time}")

# %% [markdown]
# ## Instructions
#
# - Answer all questions and place answers in the code cells provided and ensure all outputs are displayed.
#
# - You have **15 minutes** at the end of the lecture to complete these tasks.
#
# - Save (**rename**) the notebook as `checkpoint03_lastname.ipynb` and submit to Canvas before leaving class at 12:15 p.m.

# %% [markdown]
# ## Question (20 pts)
# ### Predicting Storm Type
#
# **a.** Create a function named: `storm_type(cape, shear)` that that returns:
#
# - Ordinary
# - Multicell
# - Supercell
#
# based on the figure below.
#
# **b.** Then use a for loop to classify the following three cases:
#
# `cape_values  = [500, 1800, 3000]`
#
# `shear_values = [10, 30, 50]`
#
# **Use these simplified rules:**
#
# CAPE < 1000 and shear < 20:
#     Ordinary
#
# CAPE >= 1000 and shear < 40:
#     Multicell
#
# CAPE >= 1000 and shear >= 40:
#     Supercell
#
# **PRINT** the result for each case! For example:   **CAPE=500  Shear=10  --> Ordinary**
#
# <br>
#
#
# <figure style="display: table; text-align: left; width: 40%;">
#     <img src="attachment:fe219790-a81f-4172-8e84-1088d9c89a95.png" style="width: 100%; height: auto;">
#     <figcaption style="margin-top: 5px; line-height: 1.1; font-style: italic; text-align: justify;">
#         Figure: Morphology of thunderstorms that theoretically develop under different wind shear and convective available potential energy (CAPE) situations.
#     </figcaption>
# </figure>

# %%
# Question Answer 
# Hint: Dr. L - I would use the zip command here!

# %% [markdown]
# ## AI Use Disclosure </span> <span style="color:red"> (Required)</span>
#
# ### AI Used?
#
# - [ ] No
# - [ ] Yes
#
# ### Tool Used
#
# Tool:
#
# ### Prompt(s) Used
#
# Copy and paste the prompt(s) you entered.
#
# ### How Was the AI Output Used?
#
# - [ ] Helped explain a concept
# - [ ] Suggested code
# - [ ] Debugged code
# - [ ] Helped format Markdown
# - [ ] Other
