# %% [markdown]
# # MET 3601 <span style="color:green"> Checkpoint #4</span>, <span style="color:red"> Points: 20</span>
# ## NumPy Arrays and Scientific Data Analysis

# %%
from IPython.display import display, Markdown

name = input("Please enter your first and last name: ")

# Prints the name in bold green text
display(Markdown(f"### Welcome, <span style='color: green;'>**{name}**</span>!"))

# %%
from datetime import datetime

# Get current system date and time
now = datetime.now()

# %I = 12-hour hour, %M = minute, %p = AM/PM
formatted_date = now.strftime("%A, %B %d, %Y")
formatted_time = now.strftime("%I:%M %p")

print(f"Current Date: {formatted_date}")
print(f"The time is: {formatted_time}")

# %% [markdown]
# ## Instructions
#
# - Answer all questions and place answers in the code cells provided and ensure all outputs are displayed.
#
# - You have **15 minutes** at the end of the lecture to complete these tasks.
#
# - Save (**rename**) the notebook as `checkpoint04_lastname.ipynb` and submit to Canvas before leaving class at 12:15 p.m.

# %% [markdown]
# ## Question 1 (2 pts)
# ### Read the Data File
#
# ```Python
# data = np.loadtxt(path + file, skiprows=1, max_rows=?)
# ```
#
# *You will need lecture 8_numpy_reading_and_stat_functions for this problem.*
#
# **a.** Use the code above to read the 'data'. You will need to provide the `path` and `max_rows`.
# **b.** Print the 'data'.

# %%
#a.)
#Set path (JupyterHub)  
path = ''
file = 'nao_2026.txt'

# Linux word count command
result = !wc -l < "{path}{file}"  
nlines = int(result[0])

#Read data file using the numpy loadtxt function (see above for additional code)

# %%
#b.)

# %% [markdown]
# ## Question 2 (8 pts)
# ### Understanding Array Structure
#
# *You will need lectures 7_numpy_array_basics and 8_numpy_reading_and_stat_functions for this problem.*
#
# **a.** Extract the NAO values only from the 'data' and store them in an array called `naov`.
# **b.** Use the appropriate numpy methods to obtain (i.e., print) the # of rows and the total # of NAO values.
# **c.** Use your results in b) and the relevant numpy method to determine whether `naov` is a 1D or 2D array? Print the result.

# %%
#Answer a, b, and c here  (use code!)

#a.)


#b.)


#c.)

# %% [markdown]
# ## Question 3 (10 pts)
# ### Statistical Thinking
#
# *You will need lecture 8_numpy_reading_and_stat_functions for this problem.*
#
# **a.** Use the `input` function to enter the year and then print out the corresponding NAO indices for that year.
# **b.** Extract only the years from the 'data' and store them in an array called `yy`. Print the years.
# **c.** Use the relevant numpy method to find the maximum NAO value for the year you selected. Use an f-string to print the year and value.

# %%
# Question 2 answer

#a.)



#b.)



#c.)

# %% [markdown]
# ## AI Use Disclosure </span> <span style="color:red"> (Required)</span>
#
# ### AI Used?
#
# - [ ] No
# - [ ] Yes
#
# ### Tool Used
#
# Tool:
#
# ### Prompt(s) Used
#
# Copy and paste the prompt(s) you entered.
#
# ### How Was the AI Output Used?
#
# - [ ] Helped explain a concept
# - [ ] Suggested code
# - [ ] Debugged code
# - [ ] Helped format Markdown
# - [ ] Other
