# %% [markdown]
# # MET 3601 <span style="color:green"> Checkpoint #2</span>, <span style="color:red"> Points: 20</span>
# ## Week 2: Python Fundamentals and Data Objects

# %%
from IPython.display import display, Markdown

name = input("Please enter your first and last name: ")

# Prints the name in bold green text
display(Markdown(f"### Welcome, <span style='color: green;'>**{name}**</span>!"))

# %%
from datetime import datetime

# Get current system date and time
now = datetime.now()

# %I = 12-hour hour, %M = minute, %p = AM/PM
formatted_date = now.strftime("%A, %B %d, %Y")
formatted_time = now.strftime("%I:%M %p")

print(f"Current Date: {formatted_date}")
print(f"The time is: {formatted_time}")

# %% [markdown]
# ## Instructions
# - Answer all questions and place answers in the code cells provided and ensure all outputs are displayed.
#
# - You have **15 minutes** at the end of the lecture to complete these tasks.
#
# - Save (**rename**) the notebook as `checkpoint02_lastname.ipynb` and submit to Canvas before leaving class at 12:15 p.m.

# %% [markdown]
# ## Question 1 (8 pts)
# ### Variable Types and Conversion
#
# Given:
# ```python
# tmpf = "85"
# ```
# *Use print statements for al of your output!*
#
# a. Determine the variable type.
# b. Convert it to a numerical value.
# c. Convert 85°F to °C.
# d. Print the result in #3 with an f-string showing `two decimal places`.

# %%
# Question 1 Answers

#a.

#b.

#c.

#d.

# %% [markdown]
# ## Question 2 (4 pts)
# ### String Interpretation
#
# Given:
# ```python
# word = "Meteorology"
# ```
#
# a. Print the first character.
# b. Print the last character.
# c. Print every other character.
# d. In a comment, briefly explain what index 0 represents.

# %%
# Question 2 Answers

#a.

#b.

#c.

#d.

# %% [markdown]
# ## Question 3 (4 pts)
# ### Choosing the Correct Data Object
#
# Identify the best Python object for each task:
#
# a. A collection that can be modified
# b. A collection that cannot be modified
# c. A collection that uses keys
# d. A collection that stores only unique values

# %%
# Question 3 Answers

# %% [markdown]
# **a.**
#
# **b.**
#
# **c.**
#
# **d.**

# %% [markdown]
# ## Question 4 (4 pts)
# ### Lists vs NumPy Arrays
#
# Given:
# ```python
# import numpy as np
# a = [1,2,3]
# b = np.array([1,2,3])
# ```
#
# *Use print statements for al of your output!*
#
# a. Calculate the result of `a * 3`.
# b. Calculate the result of `b * 3`.

# %%
# Question 4 Answers

#a.

#b.

# %% [markdown]
# ## AI Use Disclosure </span> <span style="color:red"> (Required)</span>
#
# ### AI Used?
#
# - [ ] No
# - [ ] Yes
#
# ### Tool Used
#
# Tool:
#
# ### Prompt(s) Used
#
# Copy and paste the prompt(s) you entered.
#
# ### How Was the AI Output Used?
#
# - [ ] Helped explain a concept
# - [ ] Suggested code
# - [ ] Debugged code
# - [ ] Helped format Markdown
# - [ ] Other
