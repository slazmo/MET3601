# %% [markdown]
# # MET 3601 Checkpoint #5
# ## Understanding Plotting with Matplotlib

# %%
from IPython.display import display, Markdown

name = input("Please enter your first and last name: ")

# Prints the name in bold green text
display(Markdown(f"### Welcome, <span style='color: green;'>**{name}**</span>!"))

# %%
from datetime import datetime, timezone
from zoneinfo import ZoneInfo

utc_now = datetime.now(timezone.utc)
et_now  = utc_now.astimezone(ZoneInfo("America/New_York"))

# %I = 12-hour hour, %M = minute, %p = AM/PM
formatted_date = et_now.strftime("%A, %B %d, %Y")
formatted_time = et_now.strftime("%I:%M %p")

print(f"Current Date: {formatted_date}")
print(f"The time is:  {formatted_time}")

# %% [markdown]
# ## Instructions
#
# - Answer all questions and place answers in the code cells provided and ensure all outputs are displayed.
#
# - You have **15-20 minutes** at the end of the lecture to complete these tasks.
#
# - Save (**rename**) the notebook as `checkpoint05_lastname.ipynb` and submit to Canvas before leaving class at 12:15 p.m.

# %% [markdown]
# ## Question 1 (10 pts)
# ### Calculating and Visualizing Daily Minimum Temperature Anomalies
#
# Consider the following daily minimum temperatures in °F from KMLB for February 2026.
# ```python
# tmin_feb26 = [26.1, 26.1, 28.9, 30.0, 42.1, 37.9, 37.9, 44.1, 43.0, 43.0, 48.9, 53.1, 54.0, 54.0, 55.0, 64.0, 55.9, 59.0, 59.0, 59.0, 63.0, 63.0, 43.0, 37.0, 35.1, 35.1, 50.0, 66.0]
# ```
#
# **a.** Calculate the daily minimum temperature anomalies for February 2026 using:
#
# *anomaly = observed temperature − climatological mean temperature*
#
# Store the results in a NumPy array named `feb_tmin_anom` and print the array. Note that the February 1991-2020 mean minimum temperature at KMLB is 52.8°F (see climate normals table below).  2 pts
#
# **b.** Create an array named `days` containing the day numbers for February 2026 using np.arange(). Use `len(tmin_feb26)` to determine the number of days. Print the `days` array. 3 pts
#
# **c.** Create a line plot (1 pt) of the daily minimum temperature anomalies using a solid blue line. Include (1 pt each):
# ```Python
#  x axis label --> February 2026
#  y axis label --> Daily Minimum Temperature Anomaly (°F)
#  Title  --> KMLB ASOS
#  A Legend identifying the plotted data
# ```
# **d.** Calculate the *mean* minimum temperature anomaly for the month using a NumPy method. Store the result in a variable named `avg_anom` and print the value using an f-string. 1 pt
#
# **e.** Use an if/elif/else block to determine whether February 2026 was: 2 pts
#
# - warmer than normal (avg_anom > 0)
# - cooler than normal (avg_anom < 0)
# - exactly normal (avg_anom == 0)
#
# Use an f-string to print an appropriate message.
#
# **Extra Credit:** 2 pts
# Add the following reference lines to your plot:
# - a dashed black line at y = 0
# - a solid red line at y = avg_anom
#
# Include an appropriate legend label for the mean anomaly line.
#
#
# ![Screenshot 2026-08-15 at 2.58.58 PM.png](attachment:84871ce8-8a8e-4109-84e8-320a4a80a942.png)
#
# ![Screenshot 2026-08-15 at 2.31.17 PM.png](attachment:e6b48159-d454-46ae-9d53-0d95a733c3ef.png)

# %%
#Import libraries
import numpy as np

# %%
#a.) Answer

# %%
#b.) Answer

# %%
#c.) Plot
import matplotlib.pyplot as plt
plt.figure(figsize=(10,4))

# %%
#d.)

# %%
#e.)

# %% [markdown]
# ## AI Use Disclosure </span> <span style="color:red"> (Required)</span>
#
# ### AI Used?
#
# - [ ] No
# - [ ] Yes
#
# ### Tool Used
#
# Tool:
#
# ### Prompt(s) Used
#
# Copy and paste the prompt(s) you entered **AND** the code you added.
#
#
#
# ### How Was the AI Output Used?
#
# - [ ] Helped explain a concept
# - [ ] Suggested code
# - [ ] Debugged code
# - [ ] Helped format Markdown
# - [ ] Other
