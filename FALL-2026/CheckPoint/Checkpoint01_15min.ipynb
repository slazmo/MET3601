# %% [markdown]
# # MET 3601 <span style="color:green"> Checkpoint #1</span>, <span style="color:red"> Points: 20</span>
# ## Week 1: JupyterLab, Markdown, and Basic Python

# %%
from IPython.display import display, Markdown

name = input("Please enter your first and last name: ")

# Prints the name in bold green text
display(Markdown(f"### Welcome, <span style='color: green;'>**{name}**</span>!"))

# %%
from datetime import datetime

# Get current system date and time
now = datetime.now()

# %I = 12-hour hour, %M = minute, %p = AM/PM
formatted_date = now.strftime("%A, %B %d, %Y")
formatted_time = now.strftime("%I:%M %p")

print(f"Current Date: {formatted_date}")
print(f"The time is: {formatted_time}")

# %% [markdown]
# ## Instructions
#
# - Answer all questions and place answers in the code cells provided and ensure all outputs are displayed.
#
# - You have **15 minutes** at the end of the lecture to complete these tasks.
#
# - Save (**rename**) the notebook as `checkpoint01_lastname.ipynb` and submit to Canvas before leaving class at 12:15 p.m.

# %% [markdown]
# ## Question 1 (10 pts)
# ### Markdown Basics
#
# Create a **new Markdown cell** below this question that contains:
#
# **a.** Your full name (in italics)
# **b.** Your major
# **c.** One weather or climate topic that interests you
#
# **d.** Also include:
#
# - A bulleted list (any 3 items, rated G)
# - *On separate lines*, a list of any items using letters (i.e., A, B, C)
# - A working hyperlink to your favorite weather-related website

# %%
### Question 1 Answers

# %% [markdown]
# ## Question 2 (4 pts)
# ### Creating Variables
#
# Create/populate the following variables with your personal information:
#
# ```python
# name
# major
# graduation_year
# ```
#
# Print all information using a **single f-string** according to...
#
# My name is _________, my major is __________, and I expect to graduate in ____.

# %%
# Question 2 Answers

# %% [markdown]
# ## Question 3 (4 pts)
# ### Navigating the Linux World in a Notebook
#
# Perform the following Linux tasks in the cell below
#
# **a.** Print the working directory
# **b.** Change your directory to Lectures
# **c.** Print the working directory
# **d.** List the contents of the Lectures directory

# %%
# Question 3 Answer

# %% [markdown]
# ## Question 4 (2 pts)
# ### Latex Equations
#
# **a.** Create a left-justified `markdown equation` for the virtual temperature approximation, i.e. Tv ~ T(1 + 0.61w), where w is the mixing ratio (kg/kg) and T is the temperature (K).
# <br>
# **b.** *Embed* the same equation in the following sentence (replace the blank with the equation!):
#
# The virtual temperature of an air parcel can be calculated using _________________, which accounts for the moisture content of the atmosphere.

# %%
# Question 4 Answers

# %% [markdown]
# ## AI Use Disclosure </span> <span style="color:red"> (Required)</span>
#
# ### AI Used?
#
# - [ ] No
# - [ ] Yes
#
# ### Tool Used
#
# Tool:
#
# ### Prompt(s) Used
#
# Copy and paste **all** AI prompt(s) you entered to answer these questions.
#
# ### How Was the AI Output Used? Select all that apply.
#
# - [ ] Helped explain a concept
# - [ ] Suggested code
# - [ ] Debugged code
# - [ ] Helped format Markdown
# - [ ] Other
