# %% [markdown]
# ### MET 3601 Syntax Problem #13
# ![Screenshot 2024-11-11 at 2.43.08 PM.png](attachment:00c5e7e1-d954-4ff1-a062-d5bb7d3cacb3.png)

# %%
from metpy.units import units

sigma = 5.67e-8 * units('W / m^2 / K^4')

print(sigma)
