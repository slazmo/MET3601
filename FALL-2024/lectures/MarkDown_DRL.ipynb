# %% [markdown]
# Headings
# Use the number sign (#) followed by a blank space for notebook titles and section headings:
# # for titles
# ## for major headings
# ### for subheadings
# #### for 4th level subheadings

# %% [markdown]
# Use the following code to emphasize text:
# Bold text: __string__ or **string**
# Italic text: _string_ or *string*

# %% [markdown]
# ## DR L added this Markdown Box
# 1. Using a programming language of your choice (e.g., R, Python), calculate the blackbody curves for the following temperatures: 220 K, 240 K, 260 K, 280 K, and 300 K. There should be 5 curves per graph and three graphs total for this part of the problem.
#
# FIRST GRAPH: wavelength (µm) on the x-axis versus intensity B(T) (W $m^{-2}$) $sr^{-1}$ $µm^{-1}$) on the y axis. Use a 𝛿𝝀 = $10^{-6}$ m for values of ranging from 1 to 90 µm and a 𝛿𝝀 = $10^{-5}$ m for values ranging 90 to 150 µm (i.e., the plot should cover the wavelength interval of 1 µm to 150 µm – just reduce the number of points for gamma > 90 µm), where $c_{1}$ = 1.191042 x $10^{8}$ W $m^{-2}$ $sr^{-1}$ $µm^{4}$ and $c_{2}$ = 1.4387752 x $10^{4}$ µm K.
#
# ### TO SEE MY COMMENTS - search for "DRL"

# %% [markdown]
# $\delta$

# %% [markdown]
# $\beta$

# %% [markdown]
# $\mu$

# %%
"\U0001D706"
# Out:
# '𝜆'

# %% [markdown]
# ####See IBM Markdown Cheat Sheet at
#
# https://www.ibm.com/docs/en/db2-event-store/2.0.0?topic=notebooks-markdown-jupyter-cheatsheet

# %% [markdown]
# Bullets
# To create a circular bullet point, use one of the following methods. Each bullet point must be on its own line.
# A hyphen (-) followed by one or two spaces, for example:
# - Bulleted item
#
# A space, a hyphen (-) and a space, for example:
# - Bulleted item
#
# An asterisk (*) followed by one or two spaces, for example:
# * Bulleted item

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.
# If it’s a note, you don’t have to include the word “Note”.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Up to you:</b> Use green boxes sparingly, and only for some specific
# purpose that the other boxes can't cover. For example, if you have a lot
# of related content to link to, maybe you decide to use green boxes for
# related links from each section of a notebook.
# </div>

# %% [markdown]
# ###See
#
# https://towardsdatascience.com/write-markdown-latex-in-the-jupyter-notebook-10985edb91fd
#
# ![Screenshot 2024-08-28 at 10.32.49 AM.png](attachment:9434a982-82f7-493f-9056-7e7c74f4894e.png)
